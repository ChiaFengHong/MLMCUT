# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiaFengHong/MLMCUT/blob/master/table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'http://insideairbnb.com/get-the-data.html'
response = urlopen(url)
html = BeautifulSoup(response)

# %%
from urllib.request import urlretrieve
tables = html.find_all('table')
regions = html.find_all('h2')
for (i, t) in enumerate(tables):
  r = regions[i].text
  body = t.find('tbody')
  row = body.find_all('tr')[3]
  country = row.find_all('td')[1].text
  listing = row.find_all('td')[2].find('a')['href']
  if 'United States' in r:
    print(country, listing)
    fname = country + '.csv'
    try:
      urlretrieve(listing, fname)
    except:
      print('跳過')
# Out:
# Asheville http://data.insideairbnb.com/united-states/nc/asheville/2019-06-26/visualisations/listings.csv
# Austin http://data.insideairbnb.com/united-states/tx/austin/2019-05-14/visualisations/listings.csv
# Boston http://data.insideairbnb.com/united-states/ma/boston/2019-05-19/visualisations/listings.csv
# Broward County http://data.insideairbnb.com/united-states/fl/broward-county/2019-05-19/visualisations/listings.csv
# Cambridge http://data.insideairbnb.com/united-states/ma/cambridge/2019-06-24/visualisations/listings.csv
# Chicago http://data.insideairbnb.com/united-states/il/chicago/2019-05-19/visualisations/listings.csv
# Clark County, NV http://data.insideairbnb.com/united-states/nv/clark-county-nv/2019-06-25/visualisations/listings.csv
# Columbus http://data.insideairbnb.com/united-states/oh/columbus/2019-05-18/visualisations/listings.csv
# Denver http://data.insideairbnb.com/united-states/co/denver/2019-05-29/visualisations/listings.csv
# ...

# %%
import glob
import pandas as pd

total_df = pd.DataFrame()
for fn in glob.glob('*.csv'):
  country = fn.split('.')[0]
  df1 = pd.read_csv(fn, encoding='utf-8')
  #如果整行設同一個值
  df1['country'] = country
  
  #連接兩個df,橫的連或直的連(Axis)
  total_df = pd.concat([total_df, df1],ignore_index=True)
total_df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         PassengerId  Survived  ...  reviews_per_month        room_type
# 0               NaN       NaN  ...               1.81  Entire home/apt
# 1               NaN       NaN  ...               1.37     Private room
# 2               NaN       NaN  ...               1.57     Private room
# 3               NaN       NaN  ...               0.31  Entire home/apt
# ...

# %%
from google.colab import files
#儲存檔案
total_df.to_csv('total.csv', encoding='utf-8', index=False)
files.download('total.csv')

# %%
#行操作:[行名字]
total_df['country'].unique()
# Out:
# array(['Twin Cities MSA', 'titanic_knn', 'Oakland', 'New York City',
#        'Rhode Island', 'San Francisco', 'Denver', 'Portland', 'titanic',
#        'Nashville', 'Chicago', 'Pacific Grove', 'San Diego', 'Austin',
#        'Asheville', 'Salem, OR', 'Boston', 'Hawaii', 'Los Angeles',
#        'Washington, D', 'Cambridge', 'Broward County', 'total',
#        'Santa Clara County', 'Clark County, NV', 'Seattle', 'New Orleans',
#        'Columbus', 'Jersey City', 'Santa Cruz County'], dtype=object)

# %%
total_df['country'].value_counts()
# Out:
# total                 256299
# New York City          48801
# Los Angeles            43954
# Hawaii                 25706
# San Diego              12333
# Austin                 11792
# Clark County, NV        9369
# Broward County          9165
# Washington, D           8994
# Seattle                 8926
# Chicago                 8169
# San Francisco           7575
# Santa Clara County      6972
# Nashville               6962
# New Orleans             6962
# Twin Cities MSA         6607
# Boston                  6241
# Portland                5585
# Denver                  4659
# Rhode Island            3588
# Oakland                 3167
# Jersey City             2877
# Asheville               2170
# Santa Cruz County       1744
# Cambridge               1369
# Columbus                1363
# titanic                  418
# titanic_knn              418
# Pacific Grove            228
# Salem, OR                185
# Name: country, dtype: int64

# %%
#https://seaborn.pydata.org/api.html
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
plt.figure(figsize = (28, 10))
g = sns.countplot(x=total_df['country'] )
g.set_xticklabels(g.get_xticklabels(), rotation=30)
plt.savefig('country.png')
g

# %%
plt.figure(figsize = (28, 10))
sns.countplot(y=total_df['country'], hue=total_df['room_type'])
plt.savefig('country.png')

# %%
total_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'availability_365',
#        'calculated_host_listings_count', 'counrty', 'country', 'host_id',
#        'host_name', 'id', 'last_review', 'latitude', 'longitude',
#        'minimum_nights', 'name', 'neighbourhood', 'neighbourhood_group',
#        'number_of_reviews', 'price', 'reviews_per_month', 'room_type'],
#       dtype='object')

# %%
# Series: 比較 & 相等, 擴充到每一個
# 篩選: df[跟你的資料筆數依樣多的Ture/False]
plt.figure(figsize=(14, 10))
fs = total_df["country"] == "New York City"
ny_df = total_df[fs]
g = sns.distplot(ny_df["price"])
g.set_xticklabels(range(0, 10000, 50))
g

# %%
# !pip install rake-nltk
# https://github.com/csurfer/rake-nltk
from rake_nltk import Rake
# .iloc: ["first row", "second row"]
s = total_df.iloc[0]["name"]

r = Rake()
r.extract_keywords_from_text(s)
r.get_ranked_phrases()
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# ...
# ['cozy artist ’', 'entire home', 'wifi', 'netflix', 'abode']

# %%
# 整行轉換: apply
def phrase(s):
    r = Rake()
    r.extract_keywords_from_text(s)
    return str(r.get_ranked_phrases())
# head: 拿出頭幾列
# astype: 把整行轉換某個型態
df10000 = total_df.head(10000)
df10000["phrases"] = df10000["name"].astype("str").apply(phrase)
df10000.to_csv("df10000.csv", encoding="utf-8", index=False)
df10000
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       PassengerId  ...                                            phrases
# 0             NaN  ...  ['cozy artist ’', 'entire home', 'wifi', 'netf...
# 1             NaN  ...  ['private bath', 'near downtown', 'charming', ...
# 2             NaN  ...       ['light rail', 'parks', 'lakes', 'downtown']
# 3             NaN  ...         ['minneapolis', 'edina', 'creek', 'cabin']
# 4             NaN  ...                ['organic breakfast', 'attic loft']
# 5             NaN  ...              ['mpls metro lakeside summer rental']
# 6             NaN  ...                                     ['guest room']
# ...

# %%
# groupby: 以某一個欄位做結合
countdf = pd.DataFrame()
temp = total_df.groupby("host_id").count().reset_index()
countdf["host_id"] = temp["host_id"]
countdf["bnb_count"] = temp["id"]
countdf
# Out:
#             host_id  bnb_count
# 0              20.0          2
# 1              23.0          4
# 2              29.0          2
# 3              46.0          2
# 4              59.0          2
# 5             470.0          2
# 6             521.0          2
# 7             615.0          6
# 8             666.0          6
# 9             678.0         14
# 10            767.0          2
# 11            783.0          2
# 12            862.0          2
# 13            908.0         50
# 14            933.0          4
# 15            971.0          2
# 16            988.0          4
# 17            990.0          4
# 18           1031.0          2
# 19           1169.0          2
# 20           1346.0          2
# 21           1408.0          2
# 22           1496.0          4
# 23           1585.0          2
# 24           1617.0          2
# 25           1618.0          4
# 26           1838.0          2
# 27           1877.0          2
# 28           1957.0          4
# ...

# %%
countdf[countdf["bnb_count"] >= 5]
# Out:
#             host_id  bnb_count
# 7             615.0          6
# 8             666.0          6
# 9             678.0         14
# 13            908.0         50
# 31           2140.0         10
# 38           2466.0          6
# 46           2787.0         12
# 47           2798.0         10
# 67           3415.0         12
# 68           3514.0         14
# 69           3518.0         14
# 72           3768.0         14
# 79           4434.0         10
# 85           4645.0          6
# 98           5117.0          6
# 106          5656.0          8
# 111          5803.0          6
# 122          6527.0          6
# 124          6829.0         12
# 125          7054.0         10
# 126          7086.0          6
# 138          7351.0          6
# 146          7532.0          8
# 147          7549.0          8
# 149          7620.0         14
# 156          7878.0          6
# 165          8145.0          6
# 169          8229.0         12
# 172          8435.0          6
# ...

# %%
plt.figure(figsize=(20, 20))
sns.scatterplot(x=total_df["price"], y=total_df["number_of_reviews"], hue=total_df["country"])

# %%
total_df["country"].value_counts()
# Out:
# total                 256299
# New York City          48801
# Los Angeles            43954
# Hawaii                 25706
# San Diego              12333
# Austin                 11792
# Clark County, NV        9369
# Broward County          9165
# Washington, D           8994
# Seattle                 8926
# Chicago                 8169
# San Francisco           7575
# Santa Clara County      6972
# Nashville               6962
# New Orleans             6962
# Twin Cities MSA         6607
# Boston                  6241
# Portland                5585
# Denver                  4659
# Rhode Island            3588
# Oakland                 3167
# Jersey City             2877
# Asheville               2170
# Santa Cruz County       1744
# Cambridge               1369
# Columbus                1363
# titanic                  418
# titanic_knn              418
# Pacific Grove            228
# Salem, OR                185
# Name: country, dtype: int64

# %%
# replace: 
plt.figure(figsize=(20, 20))
temp = total_df[(total_df["country"] == "New York City") | (total_df["country"] == "Los Angeles")]
cmap = {"New York City":"NY", "Los Angeles":"LA"}
temp["country"] = temp["country"].replace(cmap)
rmap = {'Private room':"Private", 'Entire home/apt':"Apt", 'Shared room':"Shared"}
temp["room"] = temp["room_type"].replace(rmap)
grid = sns.FacetGrid(temp, row="country", col="room")
grid.map(sns.distplot, "price", kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
